# %% [markdown]
# <a href="https://colab.research.google.com/github/davidalifff/PCVK_Genap_2023/blob/main/Week_5_Ril.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
img_female = cv.imread('/content/drive/MyDrive/PCVK/female.tiff')
img_femaleRGB = cv.cvtColor(img_female,cv.COLOR_BGR2RGB)
plt.imshow(img_femaleRGB)

# %%
print('Gamma Correction pada citra ')
print('----------------------------------')
try:
  gamma = int(input('Masukkan Nilai Gamma: '))
except ValueError:
  print('Error, Not a Number')

original = cv.cvtColor(img_female2,cv.COLOR_BGR2RGB)
gamma_image = np.zeros(original.shape, original.dtype)
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      gamma_image[y,x,c] = np.clip(255 * pow(original[y,x,c] / 255, (1 / gamma)), 0, 255)

final_frame = cv.hconcat((original, gamma_image))
cv2_imshow(final_frame)
# Out:
# Gamma Correction pada citra
# ----------------------------------
# Masukkan Nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FB8645E6700>

# %%
original = cv.imread('/content/drive/MyDrive/PCVK/female.tiff', cv.IMREAD_GRAYSCALE)
originalGS = cv.cvtColor(original, cv.COLOR_BGR2RGB)

depth_image = np.zeros(originalGS.shape, originalGS.dtype)


bit_depth = 2
level = 255 / (pow(2,bit_depth)-1)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
      depth_image[y,x] = np.clip(round(originalGS[y,x,0] / level) * level, 0, 255);

final_frame = cv.hconcat((originalGS,depth_image))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FB8667B4A00>

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK/noises/*.jpg'):
  n = cv.imread(img)
  cv_img.append(n)

dst = cv_img[0]
noise_number = 4 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0 :
    pass
  else:
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
  mse = np.mean((original - compressed) ** 2)
  if(mse == 0):
    return 100
  max_pixel = 255.0
  psnr = 20* log10(max_pixel / sqrt(mse))
  return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah ', psnr, '(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah  27.54128631970714 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FB864F56D00>

# %%
dst = cv_img[0]
noise_number = 29 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0: pass
  else : 
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah', psnr,'(dB)')
galaxy_frame = cv.hconcat((original,dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.519586672258946 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FB85306D850>

# %%
dst = cv_img[0]
noise_number = 59 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0: pass
  else : 
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah', psnr,'(dB)')
galaxy_frame = cv.hconcat((original,dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.486225446211066 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FB866837A00>

# %%
dst = cv_img[0]
noise_number = 79 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0: pass
  else : 
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah', psnr,'(dB)')
galaxy_frame = cv.hconcat((original,dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.496890018049974 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FB864F8BC70>

# %%
dst = cv_img[0]
noise_number = 99 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0: pass
  else : 
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah', psnr,'(dB)')
galaxy_frame = cv.hconcat((original,dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.50507458018701 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FB853050430>

# %%
#Tugas No 4
img_couple = cv.imread('/content/drive/MyDrive/PCVK/couple.tiff')
img_couple2 = cv.cvtColor(img_couple,cv.COLOR_BGR2RGB)
t=img_couple2.shape[0]
l=img_couple2.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(img_couple2.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 30, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 30, (255,255,255), -1)

result = img_couple2 & mask & mask1 





circle_frame = cv.hconcat((img_couple2, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256

# %%
# OR
img_couple2 = cv.cvtColor(img_couple,cv.COLOR_BGR2RGB)
t=img_couple2.shape[0]
l=img_couple2.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(img_couple2.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = img_couple2 | mask & mask1 

circle_frame = cv.hconcat((img_couple2, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256

# %%
# NOT
img_couple2 = cv.cvtColor(img_couple,cv.COLOR_BGR2RGB)
t=img_couple2.shape[0]
l=img_couple2.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(img_couple2.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = ~img_couple2 & ~mask & ~mask1 

circle_frame = cv.hconcat((img_couple2, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256

# %%
# NAND
img_couple2 = cv.cvtColor(img_couple,cv.COLOR_BGR2RGB)
t=img_couple2.shape[0]
l=img_couple2.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(img_couple2.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = ~img_couple2 & mask & mask1 

circle_frame = cv.hconcat((img_couple2, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256

# %%
# XOR
img_couple2 = cv.cvtColor(img_couple,cv.COLOR_BGR2RGB)
t=img_couple2.shape[0]
l=img_couple2.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(img_couple2.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = img_couple2 ^ mask & mask1 

circle_frame = cv.hconcat((img_couple2, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256
