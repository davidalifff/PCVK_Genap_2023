# %% [markdown]
# <a href="https://colab.research.google.com/github/davidalifff/PCVK_Genap_2023/blob/main/Week2%20-%20Done.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kojeng.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kojeng.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black)

# %%
#perhatikan koordinat titik" pt1 dan pt2
cv.rectangle(black,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black)

# %%
cv.rectangle(black,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black)

# %%
cv.circle(black,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black)

# %%
cv.line(black,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black)

# %%
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(black,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(black)

# %%
black2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black2)

# %%
vertices=np.array([[100,300],
                   [200,200],
                   [400,300],
                   [200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts=vertices.reshape((-1,1,2))#fungsi reshape adalah mengubah bentuk array tanpa mengubah data
pts#dimana pada kasus ini data data akan dibentuk menjadi per kolom menambahkan kurung siku
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black2)

# %% [markdown]
# #TUGAS

# %%
plt.imshow(img_gray,cmap='RdYlGn')

# %%
plt.imshow(img_gray,cmap='GnBu')

# %%
img_kojeng = cv.imread('/content/drive/MyDrive/PCVK/kojeng2.jpeg')
img_kojeng = cv.cvtColor(img_kojeng,cv.COLOR_BGR2RGB)
crop = img_kojeng[20:115, 25:120]
plt.imshow(crop)

# %%
#4 Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# Method zeros digunakan untuk membuat array kosong
zeros = np.zeros(img_kojeng.shape[:2], dtype="uint8")

# Buat variable RGB untuk dilakukan split warna pada gambar
R,G,B = cv.split(img_kojeng)

# Tampilkan warna merah
red = cv.merge([R,zeros,zeros])

#Tampilkan baris 5:30
crop = red[5:30]
plt.imshow(crop)

# %%
img_kojeng1 = cv.imread('/content/drive/MyDrive/PCVK/kojeng.jpeg')
img_kojeng1 = cv.cvtColor(img_kojeng1,cv.COLOR_BGR2RGB)
image = img_kojeng1

for r in range(5) :
  start = np.random.randint(0,736)
  end = np.random.randint(0,736)
  R = np.random.randint(0,255)
  G = np.random.randint(0,255)
  B = np.random.randint(0,255)
  color = (R,G,B)
  startp = (start,start)
  endp = (end,end)
  thickness = 5
  image = cv.rectangle(image,startp,endp,color,thickness)

plt.imshow(image)

# %%
image = cv.flip(image,0)
plt.imshow(image)

# %%
img_face = cv.imread('/content/drive/MyDrive/PCVK/dapid3.jpeg')
img_face = cv.cvtColor(img_face,cv.COLOR_BGR2RGB)
imgsq=img_face
cv.rectangle(imgsq, (400,200),(800,400),color=(24, 56, 164),thickness=5)
cv.circle(imgsq,center=(500,300),radius=100,color=(255,0,0),thickness=2)

plt.imshow(imgsq)

# %%
t=img_face.shape[0]
l=img_face.shape[1]
print("t = ",t,"l = ",l)
# Out:
# t =  1024 l =  1024

# %%
# Tugas No 8
#Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male

img_face1 = cv.cvtColor(img_face,cv.COLOR_BGR2RGB)

cv.rectangle(img_face1,pt1=(0,300), pt2=(100,img_face1.shape[1]), color=(255,255,255), thickness=5)
R,G,B = cv.split(img_face1)

zeros = np.zeros (img_face1.shape[:2], dtype="uint8")

blue = cv.merge([zeros,zeros,B])

plt.imshow(blue)

# %%
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(img_face,text='awokawok',org=(10,1000),fontFace=font,fontScale=4,color=(255,255,255),thickness=5,lineType=cv.LINE_AA)
plt.imshow(img_face)
